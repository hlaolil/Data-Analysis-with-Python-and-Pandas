# %%
import pandas as pd

# %%
df = pd.read_csv("data/sample_lab_results.csv")

# %%
df
# Out:
#     patient_id   test_date          test_name    value   unit  reference_low  \
# 0     P0000001  2019-03-21                WBC    9.551   K/uL            4.5
# 1     P0000001  2019-03-21  total_cholesterol  225.729  mg/dL          100.0
# 2     P0000001  2019-03-21                HDL   67.620  mg/dL           40.0
# 3     P0000001  2019-03-21          potassium    4.423  mEq/L            3.5
# 4     P0000001  2019-03-21             sodium  142.463  mEq/L          136.0
# ..         ...         ...                ...      ...    ...            ...
# 995   P0000035  2020-02-26                AST   31.237    U/L           10.0
# 996   P0000035  2020-02-26      triglycerides  205.836  mg/dL            0.0
# 997   P0000035  2020-02-26         hemoglobin   15.720   g/dL           12.0
# 998   P0000035  2020-02-26    glucose_fasting  177.564  mg/dL           70.0
# 999   P0000035  2020-02-26         creatinine    1.014  mg/dL            0.6
#
# ...
